# %%
import os
import json
import pandas as pd
from tqdm import tqdm

# %%
def flatten_json(obj, prefix=''):
    flat = {}
    if isinstance(obj, dict):
        for k, v in obj.items():
            full_key = f"{prefix}.{k}" if prefix else k
            flat.update(flatten_json(v, full_key))
    elif isinstance(obj, list):
        collected = {}
        for item in obj:
            item_flat = flatten_json(item, prefix)
            for k, v in item_flat.items():
                if k not in collected:
                    collected[k] = []
                collected[k].append(v)
        for k, vlist in collected.items():
            flat[k] = '; '.join(map(str, vlist))
    else:
        flat[prefix] = obj
    return flat

# %%
def load_jsons_in_batches(base_dir, batch_size=10000):
    all_files = []
    for root, _, files in os.walk(base_dir):
        for file in files:
            if file.endswith('.json'):
                all_files.append(os.path.join(root, file))
    
    all_dfs = []
    for i in tqdm(range(0, len(all_files), batch_size), desc="Processing CVEs"):
        batch_files = all_files[i:i+batch_size]
        batch_records = []
        for path in batch_files:
            try:
                with open(path, 'r', encoding='utf-8') as f:
                    data = json.load(f)
                    flat = flatten_json(data)
                    flat['cve_json_file'] = os.path.relpath(path, base_dir)
                    batch_records.append(flat)
            except Exception as e:
                print(f"Error reading {path}: {e}")
        batch_df = pd.DataFrame(batch_records)
        all_dfs.append(batch_df)
    
    final_df = pd.concat(all_dfs, ignore_index=True)
    return final_df

# %%
base_directory = 'C:/Users/majit/Downloads/cvelistV5-main'

df_flat = load_jsons_in_batches(base_dir=base_directory, batch_size=10000)
# Out:
# Processing CVEs: 100%|██████████| 30/30 [03:31<00:00,  7.06s/it]

# %%
df_flat.head()
# Out:
#      type                        cve_json_file  \
# 0  module  .github\workflows\dist\package.json
# 1     NaN                      cves\delta.json
# 2     NaN                   cves\deltaLog.json
# 3     NaN    cves\1999\0xxx\CVE-1999-0001.json
# 4     NaN    cves\1999\0xxx\CVE-1999-0002.json
#
#                                            fetchTime  \
# 0                                                NaN
# 1                           2025-06-23T21:36:20.453Z
# 2  2025-06-23T21:36:20.453Z; 2025-06-23T21:07:03....
# 3                                                NaN
# 4                                                NaN
#
#                                      numberOfChanges  \
# 0                                                NaN
# 1                                                  1
# 2  1; 2; 9; 10; 9; 7; 12; 3; 2; 6; 53; 5; 3; 1; 8...
# 3                                                NaN
# 4                                                NaN
#
#                                            new.cveId  \
# 0                                                NaN
# 1                                      CVE-2025-6525
# 2  CVE-2025-6525; CVE-2025-52561; CVE-2025-6524; ...
# 3                                                NaN
# 4                                                NaN
#
#                                       new.cveOrgLink  \
# 0                                                NaN
# 1     https://www.cve.org/CVERecord?id=CVE-2025-6525
# 2  https://www.cve.org/CVERecord?id=CVE-2025-6525...
# 3                                                NaN
# 4                                                NaN
#
#                                       new.githubLink  \
# 0                                                NaN
# 1  https://raw.githubusercontent.com/CVEProject/c...
# 2  https://raw.githubusercontent.com/CVEProject/c...
# 3                                                NaN
# 4                                                NaN
#
#                                      new.dateUpdated  \
# 0                                                NaN
# 1                           2025-06-23T21:31:05.407Z
# 2  2025-06-23T21:31:05.407Z; 2025-06-23T21:00:13....
# 3                                                NaN
# 4                                                NaN
#
#                                        updated.cveId  \
# 0                                                NaN
# 1                                                NaN
# 2  CVE-2025-49968; CVE-2025-49969; CVE-2025-49970...
# 3                                                NaN
# 4                                                NaN
#
#                                   updated.cveOrgLink  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2  https://www.cve.org/CVERecord?id=CVE-2025-4996...  ...
# 3                                                NaN  ...
# 4                                                NaN  ...
#
#   containers.cna.x_legacyV4Record.impact.cvss.vulnerabilityResponseEffort  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   containers.cna.x_legacyV4Record.CNA_private.Current-Status  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   containers.cna.x_legacyV4Record.CNA_private.affectedKeywords  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   containers.cna.x_affectedList  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#   containers.cna.metrics.other.content.selections.namespace  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   containers.cna.metrics.other.content.selections.version  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   containers.cna.metrics.other.content.selections.values  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   containers.cna.metrics.other.content.selections.name  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   containers.cna.metrics.other.content.schemaVersion  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   containers.cna.cpeApplicability.operator
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
# [5 rows x 524 columns]

# %%
df_flat.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299126 entries, 0 to 299125
# Data columns (total 524 columns):
#  #    Column                                                                                                                  Dtype
# ---   ------                                                                                                                  -----
#  0    type                                                                                                                    object
#  1    cve_json_file                                                                                                           object
#  2    fetchTime                                                                                                               object
#  3    numberOfChanges                                                                                                         object
#  4    new.cveId                                                                                                               object
#  5    new.cveOrgLink                                                                                                          object
#  6    new.githubLink                                                                                                          object
#  7    new.dateUpdated                                                                                                         object
#  8    updated.cveId                                                                                                           object
#  9    updated.cveOrgLink                                                                                                      object
#  10   updated.githubLink                                                                                                      object
#  11   updated.dateUpdated                                                                                                     object
#  12   containers.cna.affected.product                                                                                         object
#  13   containers.cna.affected.vendor                                                                                          object
#  14   containers.cna.affected.versions.status                                                                                 object
#  15   containers.cna.affected.versions.version                                                                                object
#  16   containers.cna.descriptions.lang                                                                                        object
#  17   containers.cna.descriptions.value                                                                                       object
#  18   containers.cna.problemTypes.descriptions.description                                                                    object
#  19   containers.cna.problemTypes.descriptions.lang                                                                           object
#  20   containers.cna.problemTypes.descriptions.type                                                                           object
#  21   containers.cna.providerMetadata.dateUpdated                                                                             object
#  22   containers.cna.providerMetadata.orgId                                                                                   object
#  23   containers.cna.providerMetadata.shortName                                                                               object
#  24   containers.cna.references.tags                                                                                          object
#  25   containers.cna.references.url                                                                                           object
#  26   containers.cna.references.name                                                                                          object
#  27   containers.cna.x_legacyV4Record.CVE_data_meta.ASSIGNER                                                                  object
#  28   containers.cna.x_legacyV4Record.CVE_data_meta.ID                                                                        object
#  29   containers.cna.x_legacyV4Record.CVE_data_meta.STATE                                                                     object
#  30   containers.cna.x_legacyV4Record.affects.vendor.vendor_data.product.product_data.product_name                            object
#  31   containers.cna.x_legacyV4Record.affects.vendor.vendor_data.product.product_data.version.version_data.version_value      object
#  32   containers.cna.x_legacyV4Record.affects.vendor.vendor_data.vendor_name                                                  object
#  33   containers.cna.x_legacyV4Record.data_format                                                                             object
#  34   containers.cna.x_legacyV4Record.data_type                                                                               object
#  35   containers.cna.x_legacyV4Record.data_version                                                                            object
#  36   containers.cna.x_legacyV4Record.description.description_data.lang                                                       object
#  37   containers.cna.x_legacyV4Record.description.description_data.value                                                      object
#  38   containers.cna.x_legacyV4Record.problemtype.problemtype_data.description.lang                                           object
#  39   containers.cna.x_legacyV4Record.problemtype.problemtype_data.description.value                                          object
#  40   containers.cna.x_legacyV4Record.references.reference_data.name                                                          object
#  41   containers.cna.x_legacyV4Record.references.reference_data.refsource                                                     object
#  42   containers.cna.x_legacyV4Record.references.reference_data.url                                                           object
#  43   containers.adp.providerMetadata.orgId                                                                                   object
#  44   containers.adp.providerMetadata.shortName                                                                               object
#  45   containers.adp.providerMetadata.dateUpdated                                                                             object
#  46   containers.adp.title                                                                                                    object
#  47   containers.adp.references.tags                                                                                          object
#  48   containers.adp.references.url                                                                                           object
#  49   containers.adp.references.name                                                                                          object
#  50   cveMetadata.assignerOrgId                                                                                               object
#  51   cveMetadata.assignerShortName                                                                                           object
#  52   cveMetadata.cveId                                                                                                       object
#  53   cveMetadata.datePublished                                                                                               object
#  54   cveMetadata.dateReserved                                                                                                object
#  55   cveMetadata.dateUpdated                                                                                                 object
#  56   cveMetadata.state                                                                                                       object
#  57   dataType                                                                                                                object
#  58   dataVersion                                                                                                             object
#  59   containers.adp.problemTypes.descriptions.type                                                                           object
#  60   containers.adp.problemTypes.descriptions.cweId                                                                          object
#  61   containers.adp.problemTypes.descriptions.lang                                                                           object
#  62   containers.adp.problemTypes.descriptions.description                                                                    object
#  63   containers.adp.affected.vendor                                                                                          object
#  64   containers.adp.affected.product                                                                                         object
#  65   containers.adp.affected.cpes                                                                                            object
#  66   containers.adp.affected.defaultStatus                                                                                   object
#  67   containers.adp.affected.versions.version                                                                                object
#  68   containers.adp.affected.versions.status                                                                                 object
#  69   containers.adp.metrics.cvssV3_1.scope                                                                                   object
#  70   containers.adp.metrics.cvssV3_1.version                                                                                 object
#  71   containers.adp.metrics.cvssV3_1.baseScore                                                                               object
#  72   containers.adp.metrics.cvssV3_1.attackVector                                                                            object
#  73   containers.adp.metrics.cvssV3_1.baseSeverity                                                                            object
#  74   containers.adp.metrics.cvssV3_1.vectorString                                                                            object
#  75   containers.adp.metrics.cvssV3_1.integrityImpact                                                                         object
#  76   containers.adp.metrics.cvssV3_1.userInteraction                                                                         object
#  77   containers.adp.metrics.cvssV3_1.attackComplexity                                                                        object
#  78   containers.adp.metrics.cvssV3_1.availabilityImpact                                                                      object
#  79   containers.adp.metrics.cvssV3_1.privilegesRequired                                                                      object
#  80   containers.adp.metrics.cvssV3_1.confidentialityImpact                                                                   object
#  81   containers.adp.metrics.other.type                                                                                       object
#  82   containers.adp.metrics.other.content.timestamp                                                                          object
#  83   containers.adp.metrics.other.content.id                                                                                 object
#  84   containers.adp.metrics.other.content.options.Exploitation                                                               object
#  85   containers.adp.metrics.other.content.options.Automatable                                                                object
#  86   containers.adp.metrics.other.content.options.Technical Impact                                                           object
#  87   containers.adp.metrics.other.content.role                                                                               object
#  88   containers.adp.metrics.other.content.version                                                                            object
#  89   containers.cna.rejectedReasons.lang                                                                                     object
#  90   containers.cna.rejectedReasons.value                                                                                    object
#  91   cveMetadata.dateRejected                                                                                                object
#  92   containers.adp.affected.versions.lessThan                                                                               object
#  93   containers.adp.affected.versions.versionType                                                                            object
#  94   containers.cna.datePublic                                                                                               object
#  95   containers.cna.tags                                                                                                     object
#  96   containers.adp.metrics.other.content.dateAdded                                                                          object
#  97   containers.adp.metrics.other.content.reference                                                                          object
#  98   containers.cna.problemTypes.descriptions.cweId                                                                          object
#  99   containers.cna.x_generator.engine                                                                                       object
#  100  containers.cna.metrics.cvssV3_1.version                                                                                 object
#  101  containers.cna.metrics.cvssV3_1.baseScore                                                                               object
#  102  containers.cna.metrics.cvssV3_1.baseSeverity                                                                            object
#  103  containers.cna.metrics.cvssV3_1.vectorString                                                                            object
#  104  containers.adp.affected.versions.lessThanOrEqual                                                                        object
#  105  containers.cna.credits.lang                                                                                             object
#  106  containers.cna.credits.value                                                                                            object
#  107  containers.cna.metrics.cvssV3_1.attackComplexity                                                                        object
#  108  containers.cna.metrics.cvssV3_1.attackVector                                                                            object
#  109  containers.cna.metrics.cvssV3_1.availabilityImpact                                                                      object
#  110  containers.cna.metrics.cvssV3_1.confidentialityImpact                                                                   object
#  111  containers.cna.metrics.cvssV3_1.integrityImpact                                                                         object
#  112  containers.cna.metrics.cvssV3_1.privilegesRequired                                                                      object
#  113  containers.cna.metrics.cvssV3_1.scope                                                                                   object
#  114  containers.cna.metrics.cvssV3_1.userInteraction                                                                         object
#  115  containers.cna.title                                                                                                    object
#  116  containers.cna.x_generator                                                                                              object
#  117  containers.cna.x_legacyV4Record.CVE_data_meta.REQUESTER                                                                 object
#  118  containers.cna.x_legacyV4Record.CVE_data_meta.TITLE                                                                     object
#  119  containers.cna.x_legacyV4Record.credit                                                                                  object
#  120  containers.cna.x_legacyV4Record.generator                                                                               object
#  121  containers.cna.x_legacyV4Record.impact.cvss.baseScore                                                                   object
#  122  containers.cna.x_legacyV4Record.impact.cvss.vectorString                                                                object
#  123  containers.cna.x_legacyV4Record.impact.cvss.version                                                                     object
#  124  containers.cna.metrics.cvssV3_0.version                                                                                 object
#  125  containers.cna.metrics.cvssV3_0.baseScore                                                                               object
#  126  containers.cna.metrics.cvssV3_0.vectorString                                                                            object
#  127  containers.cna.metrics.cvssV3_0.baseSeverity                                                                            object
#  128  containers.cna.metrics.cvssV2_0.version                                                                                 object
#  129  containers.cna.metrics.cvssV2_0.baseScore                                                                               object
#  130  containers.cna.metrics.cvssV2_0.vectorString                                                                            object
#  131  containers.cna.timeline.time                                                                                            object
#  132  containers.cna.timeline.lang                                                                                            object
#  133  containers.cna.timeline.value                                                                                           object
#  134  containers.cna.credits.type                                                                                             object
#  135  containers.cna.metrics.cvssV4_0.version                                                                                 object
#  136  containers.cna.metrics.cvssV4_0.baseScore                                                                               object
#  137  containers.cna.metrics.cvssV4_0.vectorString                                                                            object
#  138  containers.cna.metrics.cvssV4_0.baseSeverity                                                                            object
#  139  containers.cna.affected.defaultStatus                                                                                   object
#  140  containers.cna.affected.versions.lessThanOrEqual                                                                        object
#  141  containers.cna.affected.versions.versionType                                                                            object
#  142  containers.cna.descriptions.supportingMedia.base64                                                                      object
#  143  containers.cna.descriptions.supportingMedia.type                                                                        object
#  144  containers.cna.descriptions.supportingMedia.value                                                                       object
#  145  containers.cna.metrics.other.content.text                                                                               object
#  146  containers.cna.metrics.other.type                                                                                       object
#  147  containers.cna.source.discovery                                                                                         object
#  148  containers.cna.affected.modules                                                                                         object
#  149  containers.cna.affected.packageName                                                                                     object
#  150  containers.cna.affected.collectionUrl                                                                                   object
#  151  containers.cna.affected.versions.lessThan                                                                               object
#  152  containers.adp.x_generator.engine                                                                                       object
#  153  containers.cna.cpeApplicability.nodes.operator                                                                          object
#  154  containers.cna.cpeApplicability.nodes.negate                                                                            object
#  155  containers.cna.cpeApplicability.nodes.cpeMatch.vulnerable                                                               object
#  156  containers.cna.cpeApplicability.nodes.cpeMatch.criteria                                                                 object
#  157  containers.cna.x_legacyV4Record.CVE_data_meta.DATE_PUBLIC                                                               object
#  158  containers.cna.metrics.other.content.value                                                                              object
#  159  containers.cna.metrics.other.content.namespace                                                                          object
#  160  containers.cna.metrics.format                                                                                           object
#  161  containers.cna.affected.collectionURL                                                                                   object
#  162  containers.cna.affected.cpes                                                                                            object
#  163  containers.cna.x_redhatCweChain                                                                                         object
#  164  containers.cna.metrics.cvssV3_0.attackComplexity                                                                        object
#  165  containers.cna.metrics.cvssV3_0.attackVector                                                                            object
#  166  containers.cna.metrics.cvssV3_0.availabilityImpact                                                                      object
#  167  containers.cna.metrics.cvssV3_0.confidentialityImpact                                                                   object
#  168  containers.cna.metrics.cvssV3_0.integrityImpact                                                                         object
#  169  containers.cna.metrics.cvssV3_0.privilegesRequired                                                                      object
#  170  containers.cna.metrics.cvssV3_0.scope                                                                                   object
#  171  containers.cna.metrics.cvssV3_0.userInteraction                                                                         object
#  172  containers.cna.source.advisory                                                                                          object
#  173  containers.cna.source.defect                                                                                            object
#  174  containers.cna.x_legacyV4Record.affects.vendor.vendor_data.product.product_data.version.version_data.affected           object
#  175  containers.cna.x_legacyV4Record.affects.vendor.vendor_data.product.product_data.version.version_data.version_affected   object
#  176  containers.cna.x_legacyV4Record.credit.lang                                                                             object
#  177  containers.cna.x_legacyV4Record.credit.value                                                                            object
#  178  containers.cna.x_legacyV4Record.impact.cvss.attackComplexity                                                            object
#  179  containers.cna.x_legacyV4Record.impact.cvss.attackVector                                                                object
#  180  containers.cna.x_legacyV4Record.impact.cvss.availabilityImpact                                                          object
#  181  containers.cna.x_legacyV4Record.impact.cvss.baseSeverity                                                                object
#  182  containers.cna.x_legacyV4Record.impact.cvss.confidentialityImpact                                                       object
#  183  containers.cna.x_legacyV4Record.impact.cvss.integrityImpact                                                             object
#  184  containers.cna.x_legacyV4Record.impact.cvss.privilegesRequired                                                          object
#  185  containers.cna.x_legacyV4Record.impact.cvss.scope                                                                       object
#  186  containers.cna.x_legacyV4Record.impact.cvss.userInteraction                                                             object
#  187  containers.cna.x_legacyV4Record.source.advisory                                                                         object
#  188  containers.cna.x_legacyV4Record.source.defect                                                                           object
#  189  containers.cna.x_legacyV4Record.source.discovery                                                                        object
#  190  containers.cna.affected.programFiles                                                                                    object
#  191  containers.cna.affected.programRoutines.name                                                                            object
#  192  containers.cna.affected.repo                                                                                            object
#  193  containers.cna.solutions.lang                                                                                           object
#  194  containers.cna.solutions.supportingMedia.base64                                                                         object
#  195  containers.cna.solutions.supportingMedia.type                                                                           object
#  196  containers.cna.solutions.supportingMedia.value                                                                          object
#  197  containers.cna.solutions.value                                                                                          object
#  198  containers.cna.exploits.lang                                                                                            object
#  199  containers.cna.exploits.value                                                                                           object
#  200  containers.cna.x_legacyV4Record.exploit.lang                                                                            object
#  201  containers.cna.x_legacyV4Record.exploit.value                                                                           object
#  202  containers.cna.x_legacyV4Record.generator.engine                                                                        object
#  203  containers.cna.x_legacyV4Record.CVE_data_meta.AKA                                                                       object
#  204  containers.cna.x_legacyV4Record.affects.vendor.vendor_data.product.product_data.version.version_data.platform           object
#  205  containers.cna.x_legacyV4Record.affects.vendor.vendor_data.product.product_data.version.version_data.version_name       object
#  206  containers.cna.metrics.cvssV3_0.exploitCodeMaturity                                                                     object
#  207  containers.cna.metrics.cvssV3_0.remediationLevel                                                                        object
#  208  containers.cna.metrics.cvssV3_0.reportConfidence                                                                        object
#  209  containers.cna.metrics.cvssV3_0.temporalScore                                                                           object
#  210  containers.cna.metrics.cvssV3_0.temporalSeverity                                                                        object
#  211  containers.cna.x_legacyV4Record.impact.cvssv3.BM.A                                                                      object
#  212  containers.cna.x_legacyV4Record.impact.cvssv3.BM.AC                                                                     object
#  213  containers.cna.x_legacyV4Record.impact.cvssv3.BM.AV                                                                     object
#  214  containers.cna.x_legacyV4Record.impact.cvssv3.BM.C                                                                      object
#  215  containers.cna.x_legacyV4Record.impact.cvssv3.BM.I                                                                      object
#  216  containers.cna.x_legacyV4Record.impact.cvssv3.BM.PR                                                                     object
#  217  containers.cna.x_legacyV4Record.impact.cvssv3.BM.S                                                                      object
#  218  containers.cna.x_legacyV4Record.impact.cvssv3.BM.UI                                                                     object
#  219  containers.cna.x_legacyV4Record.impact.cvssv3.TM.E                                                                      object
#  220  containers.cna.x_legacyV4Record.impact.cvssv3.TM.RC                                                                     object
#  221  containers.cna.x_legacyV4Record.impact.cvssv3.TM.RL                                                                     object
#  222  containers.cna.x_legacyV4Record.references.reference_data.title                                                         object
#  223  containers.adp.timeline.time                                                                                            object
#  224  containers.adp.timeline.lang                                                                                            object
#  225  containers.adp.timeline.value                                                                                           object
#  226  containers.cna.dateAssigned                                                                                             object
#  227  containers.cna.x_legacyV4Record.CVE_data_meta.DATE_ASSIGNED                                                             object
#  228  containers.cna.x_legacyV4Record.CVE_data_meta.UPDATED                                                                   object
#  229  containers.cna.cpeApplicability.nodes.cpeMatch.versionStartIncluding                                                    object
#  230  containers.cna.affected.platforms                                                                                       object
#  231  containers.cna.metrics.scenarios.lang                                                                                   object
#  232  containers.cna.metrics.scenarios.value                                                                                  object
#  233  containers.cna.metrics.cvssV2_0.accessComplexity                                                                        object
#  234  containers.cna.metrics.cvssV2_0.accessVector                                                                            object
#  235  containers.cna.metrics.cvssV2_0.authentication                                                                          object
#  236  containers.cna.metrics.cvssV2_0.availabilityImpact                                                                      object
#  237  containers.cna.metrics.cvssV2_0.confidentialityImpact                                                                   object
#  238  containers.cna.metrics.cvssV2_0.integrityImpact                                                                         object
#  239  containers.cna.x_ConverterErrors.product_name.error                                                                     object
#  240  containers.cna.x_ConverterErrors.product_name.message                                                                   object
#  241  containers.cna.x_ConverterErrors.version_name.error                                                                     object
#  242  containers.cna.x_ConverterErrors.version_name.message                                                                   object
#  243  containers.cna.cpeApplicability.nodes.cpeMatch.versionEndExcluding                                                      object
#  244  containers.cna.workarounds.lang                                                                                         object
#  245  containers.cna.workarounds.value                                                                                        object
#  246  containers.cna.x_legacyV4Record.solution.lang                                                                           object
#  247  containers.cna.x_legacyV4Record.solution.value                                                                          object
#  248  containers.cna.x_legacyV4Record.work_around.lang                                                                        object
#  249  containers.cna.x_legacyV4Record.work_around.value                                                                       object
#  250  containers.cna.affected.versions.changes.at                                                                             object
#  251  containers.cna.affected.versions.changes.status                                                                         object
#  252  containers.cna.x_legacyV4Record.CVE_data_meta.DATE_REQUESTED                                                            object
#  253  containers.cna.configurations.lang                                                                                      object
#  254  containers.cna.configurations.value                                                                                     object
#  255  containers.cna.x_legacyV4Record.configuration.lang                                                                      object
#  256  containers.cna.x_legacyV4Record.configuration.value                                                                     object
#  257  containers.cna.x_legacyV4Record.exploit                                                                                 object
#  258  containers.cna.x_legacyV4Record.solution                                                                                object
#  259  containers.cna.metrics.other.content.lang                                                                               object
#  260  containers.cna.metrics.other.content.url                                                                                object
#  261  containers.cna.x_legacyV4Record.impact.lang                                                                             object
#  262  containers.cna.x_legacyV4Record.impact.url                                                                              object
#  263  containers.cna.x_legacyV4Record.impact.value                                                                            object
#  264  containers.cna.x_legacyV4Record.CVE_data_meta.STATE_DETAIL                                                              object
#  265  containers.cna.metrics.cvssV4_0.Automatable                                                                             object
#  266  containers.cna.metrics.cvssV4_0.Recovery                                                                                object
#  267  containers.cna.metrics.cvssV4_0.Safety                                                                                  object
#  268  containers.cna.metrics.cvssV4_0.attackComplexity                                                                        object
#  269  containers.cna.metrics.cvssV4_0.attackRequirements                                                                      object
#  270  containers.cna.metrics.cvssV4_0.attackVector                                                                            object
#  271  containers.cna.metrics.cvssV4_0.privilegesRequired                                                                      object
#  272  containers.cna.metrics.cvssV4_0.providerUrgency                                                                         object
#  273  containers.cna.metrics.cvssV4_0.subAvailabilityImpact                                                                   object
#  274  containers.cna.metrics.cvssV4_0.subConfidentialityImpact                                                                object
#  275  containers.cna.metrics.cvssV4_0.subIntegrityImpact                                                                      object
#  276  containers.cna.metrics.cvssV4_0.userInteraction                                                                         object
#  277  containers.cna.metrics.cvssV4_0.valueDensity                                                                            object
#  278  containers.cna.metrics.cvssV4_0.vulnAvailabilityImpact                                                                  object
#  279  containers.cna.metrics.cvssV4_0.vulnConfidentialityImpact                                                               object
#  280  containers.cna.metrics.cvssV4_0.vulnIntegrityImpact                                                                     object
#  281  containers.cna.metrics.cvssV4_0.vulnerabilityResponseEffort                                                             object
#  282  containers.cna.rejectedReasons.supportingMedia.base64                                                                   object
#  283  containers.cna.rejectedReasons.supportingMedia.type                                                                     object
#  284  containers.cna.rejectedReasons.supportingMedia.value                                                                    object
#  285  containers.cna.x_legacyV4Record.affects.vendor.vendor_data.product.product_data.version.version_data.versions_affected  object
#  286  containers.cna.source.defects                                                                                           object
#  287  containers.cna.cpeApplicability.nodes.cpeMatch.versionEndIncluding                                                      object
#  288  containers.cna.source.found_during                                                                                      object
#  289  containers.cna.x_legacyV4Record.source.found_during                                                                     object
#  290  containers.cna.workarounds.supportingMedia.base64                                                                       object
#  291  containers.cna.workarounds.supportingMedia.type                                                                         object
#  292  containers.cna.workarounds.supportingMedia.value                                                                        object
#  293  containers.cna.credits.user                                                                                             object
#  294  containers.cna.x_ConverterErrors.DATE_PUBLIC.error                                                                      object
#  295  containers.cna.x_ConverterErrors.DATE_PUBLIC.message                                                                    object
#  296  containers.cna.x_legacyV4Record.cve_id                                                                                  object
#  297  containers.cna.x_ConverterErrors.cvssV3_0.error                                                                         object
#  298  containers.cna.x_ConverterErrors.cvssV3_0.message                                                                       object
#  299  containers.cna.metrics.cvssV3_1.exploitCodeMaturity                                                                     object
#  300  containers.cna.metrics.cvssV3_1.remediationLevel                                                                        object
#  301  containers.cna.metrics.cvssV3_1.reportConfidence                                                                        object
#  302  containers.cna.metrics.cvssV3_1.temporalScore                                                                           object
#  303  containers.cna.metrics.cvssV3_1.temporalSeverity                                                                        object
#  304  containers.cna.impacts.capecId                                                                                          object
#  305  containers.cna.impacts.descriptions.lang                                                                                object
#  306  containers.cna.impacts.descriptions.value                                                                               object
#  307  containers.cna.x_generator.env                                                                                          object
#  308  containers.cna.x_generator.origin                                                                                       object
#  309  containers.cna.x_legacyV4Record.CVE_data_meta.vendor_name                                                               object
#  310  containers.cna.x_legacyV4Record.impact                                                                                  float64
#  311  containers.cna.metrics.cvssV3_1.availabilityRequirement                                                                 object
#  312  containers.cna.metrics.cvssV3_1.confidentialityRequirement                                                              object
#  313  containers.cna.metrics.cvssV3_1.environmentalScore                                                                      object
#  314  containers.cna.metrics.cvssV3_1.environmentalSeverity                                                                   object
#  315  containers.cna.metrics.cvssV3_1.integrityRequirement                                                                    object
#  316  containers.cna.metrics.cvssV3_1.modifiedAttackComplexity                                                                object
#  317  containers.cna.metrics.cvssV3_1.modifiedAttackVector                                                                    object
#  318  containers.cna.metrics.cvssV3_1.modifiedAvailabilityImpact                                                              object
#  319  containers.cna.metrics.cvssV3_1.modifiedConfidentialityImpact                                                           object
#  320  containers.cna.metrics.cvssV3_1.modifiedIntegrityImpact                                                                 object
#  321  containers.cna.metrics.cvssV3_1.modifiedPrivilegesRequired                                                              object
#  322  containers.cna.metrics.cvssV3_1.modifiedScope                                                                           object
#  323  containers.cna.metrics.cvssV3_1.modifiedUserInteraction                                                                 object
#  324  containers.adp.descriptions.lang                                                                                        object
#  325  containers.adp.descriptions.value                                                                                       object
#  326  containers.cna.metrics.other.content.other                                                                              object
#  327  cveMetadata.requesterUserId                                                                                             object
#  328  containers.cna.x_legacyV4Record.affects.vendor.vendor_data.product.product_data.version.version_data.affected:          object
#  329  containers.cna.x_legacyV4Record.impact.cvssv3.A                                                                         object
#  330  containers.cna.x_legacyV4Record.impact.cvssv3.AC                                                                        object
#  331  containers.cna.x_legacyV4Record.impact.cvssv3.AV                                                                        object
#  332  containers.cna.x_legacyV4Record.impact.cvssv3.C                                                                         object
#  333  containers.cna.x_legacyV4Record.impact.cvssv3.I                                                                         object
#  334  containers.cna.x_legacyV4Record.impact.cvssv3.PR                                                                        object
#  335  containers.cna.x_legacyV4Record.impact.cvssv3.S                                                                         object
#  336  containers.cna.x_legacyV4Record.impact.cvssv3.SCORE                                                                     object
#  337  containers.cna.x_legacyV4Record.impact.cvssv3.UI                                                                        object
#  338  containers.cna.x_ConverterErrors.affects.error                                                                          object
#  339  containers.cna.x_ConverterErrors.affects.message                                                                        object
#  340  containers.cna.replacedBy                                                                                               object
#  341  containers.cna.x_legacyV4Record.impact.cvss.environmentalScore                                                          float64
#  342  containers.cna.x_legacyV4Record.impact.cvss.temporalScore                                                               object
#  343  containers.cna.x_legacyV4Record.impact.other                                                                            object
#  344  containers.cna.x_legacyV4Record.CVE_data_meta.DATA_ASSIGNED                                                             object
#  345  containers.cna.x_legacyV4Record.CVE_data_meta.DATE_ASSIGNEDE                                                            object
#  346  containers.cna.x_legacyV4Record.timeline.lang                                                                           object
#  347  containers.cna.x_legacyV4Record.timeline.time                                                                           object
#  348  containers.cna.x_legacyV4Record.timeline.value                                                                          object
#  349  containers.cna.x_legacyV4Record.x_advisoryEoL                                                                           object
#  350  containers.cna.x_legacyV4Record.x_affectedList                                                                          object
#  351  containers.cna.x_legacyV4Record.discoverer                                                                              object
#  352  containers.cna.x_ConverterErrors.cvssV3_1.error                                                                         object
#  353  containers.cna.x_ConverterErrors.cvssV3_1.message                                                                       object
#  354  containers.cna.metrics.other.content.ssvc                                                                               object
# ...
#  405  containers.cna.source.value                                                                                             object
#  406  containers.cna.cpeApplicability.nodes.negated                                                                           object
#  407  containers.cna.x_legacyV4Record.x_likelyAffectedList                                                                    object
#  408  containers.cna.exploits.supportingMedia.base64                                                                          object
#  409  containers.cna.exploits.supportingMedia.type                                                                            object
#  410  containers.cna.exploits.supportingMedia.value                                                                           object
#  411  containers.cna.x_legacyV4Record.affects.vendor.vendor_data.product.product_data.version.version_data.version_number     object
#  412  containers.cna.x_legacyV4Record.impact.cvss.confidentialityRequirement                                                  object
#  413  containers.cna.x_legacyV4Record.impact.cvss.environmentalSeverity                                                       object
#  414  containers.adp.metrics.format                                                                                           object
#  415  containers.adp.metrics.scenarios.lang                                                                                   object
#  416  containers.adp.metrics.scenarios.value                                                                                  object
#  417  containers.cna.x_legacyV4Record.containers.cna.affected.defaultStatus                                                   object
#  418  containers.cna.x_legacyV4Record.containers.cna.affected.product                                                         object
#  419  containers.cna.x_legacyV4Record.containers.cna.affected.vendor                                                          object
#  420  containers.cna.x_legacyV4Record.containers.cna.affected.versions.lessThanOrEqual                                        object
#  421  containers.cna.x_legacyV4Record.containers.cna.affected.versions.status                                                 object
#  422  containers.cna.x_legacyV4Record.containers.cna.affected.versions.version                                                object
#  423  containers.cna.x_legacyV4Record.containers.cna.affected.versions.versionType                                            object
#  424  containers.cna.x_legacyV4Record.containers.cna.descriptions.lang                                                        object
#  425  containers.cna.x_legacyV4Record.containers.cna.descriptions.supportingMedia.base64                                      object
#  426  containers.cna.x_legacyV4Record.containers.cna.descriptions.supportingMedia.type                                        object
#  427  containers.cna.x_legacyV4Record.containers.cna.descriptions.supportingMedia.value                                       object
#  428  containers.cna.x_legacyV4Record.containers.cna.descriptions.value                                                       object
#  429  containers.cna.x_legacyV4Record.containers.cna.impacts.capecId                                                          object
#  430  containers.cna.x_legacyV4Record.containers.cna.impacts.descriptions.lang                                                object
#  431  containers.cna.x_legacyV4Record.containers.cna.impacts.descriptions.value                                               object
#  432  containers.cna.x_legacyV4Record.containers.cna.metrics.cvssV3_1.attackComplexity                                        object
#  433  containers.cna.x_legacyV4Record.containers.cna.metrics.cvssV3_1.attackVector                                            object
#  434  containers.cna.x_legacyV4Record.containers.cna.metrics.cvssV3_1.availabilityImpact                                      object
#  435  containers.cna.x_legacyV4Record.containers.cna.metrics.cvssV3_1.baseScore                                               object
#  436  containers.cna.x_legacyV4Record.containers.cna.metrics.cvssV3_1.baseSeverity                                            object
#  437  containers.cna.x_legacyV4Record.containers.cna.metrics.cvssV3_1.confidentialityImpact                                   object
#  438  containers.cna.x_legacyV4Record.containers.cna.metrics.cvssV3_1.integrityImpact                                         object
#  439  containers.cna.x_legacyV4Record.containers.cna.metrics.cvssV3_1.privilegesRequired                                      object
#  440  containers.cna.x_legacyV4Record.containers.cna.metrics.cvssV3_1.scope                                                   object
#  441  containers.cna.x_legacyV4Record.containers.cna.metrics.cvssV3_1.userInteraction                                         object
#  442  containers.cna.x_legacyV4Record.containers.cna.metrics.cvssV3_1.vectorString                                            object
#  443  containers.cna.x_legacyV4Record.containers.cna.metrics.cvssV3_1.version                                                 object
#  444  containers.cna.x_legacyV4Record.containers.cna.metrics.format                                                           object
#  445  containers.cna.x_legacyV4Record.containers.cna.metrics.scenarios.lang                                                   object
#  446  containers.cna.x_legacyV4Record.containers.cna.metrics.scenarios.value                                                  object
#  447  containers.cna.x_legacyV4Record.containers.cna.problemTypes.descriptions.cweId                                          object
#  448  containers.cna.x_legacyV4Record.containers.cna.problemTypes.descriptions.description                                    object
#  449  containers.cna.x_legacyV4Record.containers.cna.problemTypes.descriptions.lang                                           object
#  450  containers.cna.x_legacyV4Record.containers.cna.problemTypes.descriptions.type                                           object
#  451  containers.cna.x_legacyV4Record.containers.cna.providerMetadata.orgId                                                   object
#  452  containers.cna.x_legacyV4Record.containers.cna.references.url                                                           object
#  453  containers.cna.x_legacyV4Record.containers.cna.source.discovery                                                         object
#  454  containers.cna.x_legacyV4Record.containers.cna.title                                                                    object
#  455  containers.cna.x_legacyV4Record.containers.cna.x_generator.engine                                                       object
#  456  containers.cna.x_legacyV4Record.cveMetadata.assignerOrgId                                                               object
#  457  containers.cna.x_legacyV4Record.cveMetadata.cveId                                                                       object
#  458  containers.cna.x_legacyV4Record.cveMetadata.requesterUserId                                                             object
#  459  containers.cna.x_legacyV4Record.cveMetadata.serial                                                                      float64
#  460  containers.cna.x_legacyV4Record.cveMetadata.state                                                                       object
#  461  containers.cna.x_legacyV4Record.dataType                                                                                object
#  462  containers.cna.x_legacyV4Record.dataVersion                                                                             object
#  463  containers.cna.x_generator.importer                                                                                     object
#  464  containers.cna.taxonomyMappings.taxonomyName                                                                            object
#  465  containers.cna.taxonomyMappings.taxonomyVersion                                                                         object
#  466  containers.cna.taxonomyMappings.taxonomyRelations.taxonomyId                                                            object
#  467  containers.cna.taxonomyMappings.taxonomyRelations.relationshipName                                                      object
#  468  containers.cna.taxonomyMappings.taxonomyRelations.relationshipValue                                                     object
#  469  containers.adp.metrics.other.content.value                                                                              object
#  470  containers.adp.metrics.other.content.namespace                                                                          object
#  471  containers.cna.affected.cpeApplicability.nodes.cpeMatch.criteria                                                        object
#  472  containers.cna.affected.cpeApplicability.nodes.cpeMatch.versionEndIncluding                                             object
#  473  containers.cna.affected.cpeApplicability.nodes.cpeMatch.versionStartIncluding                                           object
#  474  containers.cna.affected.cpeApplicability.nodes.cpeMatch.vulnerable                                                      object
#  475  containers.cna.affected.cpeApplicability.nodes.negate                                                                   object
#  476  containers.cna.affected.cpeApplicability.nodes.operator                                                                 object
#  477  containers.cna.metrics.other.content.Automatable                                                                        object
#  478  containers.cna.metrics.other.content.Exploitation                                                                       object
#  479  containers.cna.metrics.other.content.Technical Impact                                                                   object
#  480  containers.cna.metrics.other.content.Value Density                                                                      object
#  481  containers.cna.affected.defaulStatus                                                                                    object
#  482  containers.cna.affected.cpe                                                                                             object
#  483  containers.cna.metrics.other.content.timestamp                                                                          object
#  484  containers.cna.metrics.other.content.id                                                                                 object
#  485  containers.cna.metrics.other.content.options.Exploitation                                                               object
#  486  containers.cna.metrics.other.content.options.Automatable                                                                object
#  487  containers.cna.metrics.other.content.options.Technical Impact                                                           object
#  488  containers.cna.metrics.other.content.role                                                                               object
#  489  containers.cna.metrics.cvssV4_0.exploitMaturity                                                                         object
#  490  containers.cna.affected.lessThan                                                                                        object
#  491  containers.cna.affected.version                                                                                         object
#  492  containers.cna.affected.versionType                                                                                     object
#  493  containers.cna.x_legacyV4Record.CNA_private.Priority                                                                    object
#  494  containers.cna.x_legacyV4Record.CNA_private.STATE                                                                       object
#  495  containers.cna.x_legacyV4Record.CNA_private.TYPE                                                                        object
#  496  containers.cna.x_legacyV4Record.CNA_private.affectsSummary.affected                                                     object
#  497  containers.cna.x_legacyV4Record.CNA_private.affectsSummary.appliesTo                                                    object
#  498  containers.cna.x_legacyV4Record.CNA_private.affectsSummary.product_versions                                             object
#  499  containers.cna.x_legacyV4Record.CNA_private.affectsSummary.unaffected                                                   object
#  500  containers.cna.x_legacyV4Record.CNA_private.affectsSummary.unknown                                                      object
#  501  containers.cna.x_legacyV4Record.CNA_private.show_cvss                                                                   object
#  502  containers.cna.x_legacyV4Record.impact.cvss.Automatable                                                                 object
#  503  containers.cna.x_legacyV4Record.impact.cvss.Recovery                                                                    object
#  504  containers.cna.x_legacyV4Record.impact.cvss.Safety                                                                      object
#  505  containers.cna.x_legacyV4Record.impact.cvss.attackRequirements                                                          object
#  506  containers.cna.x_legacyV4Record.impact.cvss.providerUrgency                                                             object
#  507  containers.cna.x_legacyV4Record.impact.cvss.subAvailabilityImpact                                                       object
#  508  containers.cna.x_legacyV4Record.impact.cvss.subConfidentialityImpact                                                    object
#  509  containers.cna.x_legacyV4Record.impact.cvss.subIntegrityImpact                                                          object
#  510  containers.cna.x_legacyV4Record.impact.cvss.valueDensity                                                                object
#  511  containers.cna.x_legacyV4Record.impact.cvss.vulnAvailabilityImpact                                                      object
#  512  containers.cna.x_legacyV4Record.impact.cvss.vulnConfidentialityImpact                                                   object
#  513  containers.cna.x_legacyV4Record.impact.cvss.vulnIntegrityImpact                                                         object
#  514  containers.cna.x_legacyV4Record.impact.cvss.vulnerabilityResponseEffort                                                 object
#  515  containers.cna.x_legacyV4Record.CNA_private.Current-Status                                                              object
#  516  containers.cna.x_legacyV4Record.CNA_private.affectedKeywords                                                            object
#  517  containers.cna.x_affectedList                                                                                           object
#  518  containers.cna.metrics.other.content.selections.namespace                                                               object
#  519  containers.cna.metrics.other.content.selections.version                                                                 object
#  520  containers.cna.metrics.other.content.selections.values                                                                  object
#  521  containers.cna.metrics.other.content.selections.name                                                                    object
#  522  containers.cna.metrics.other.content.schemaVersion                                                                      object
#  523  containers.cna.cpeApplicability.operator                                                                                object
# dtypes: float64(4), object(520)
# memory usage: 1.2+ GB

# %%
df_flat.to_csv('C:/Users/majit/Downloads/dflattened_cve_dataset.csv', index=False)

# %%
non_null_counts = df_flat.notnull().sum().reset_index()
non_null_counts.columns = ['column', 'non_null_count']
non_null_counts = non_null_counts.sort_values(by='non_null_count', ascending=False)
non_null_counts.head(10)
# Out:
#                                          column  non_null_count
# 1                                 cve_json_file          299126
# 56                            cveMetadata.state          299123
# 52                            cveMetadata.cveId          299123
# 57                                     dataType          299123
# 50                    cveMetadata.assignerOrgId          299123
# 58                                  dataVersion          299123
# 22        containers.cna.providerMetadata.orgId          299123
# 54                     cveMetadata.dateReserved          299123
# 55                      cveMetadata.dateUpdated          299123
# 21  containers.cna.providerMetadata.dateUpdated          299121

# %%
non_null_counts.to_excel('C:/Users/majit/Downloads/non_null_cols.xlsx', index=False)

# %%
types_series = df_flat['containers.cna.problemTypes.descriptions.type'].dropna()

distinct_types = set(
    t.strip()
    for entry in types_series
    for t in str(entry).split(';')
)


distinct_types = sorted(distinct_types)

print("Distinct problemTypes.descriptions.type values:")
for t in distinct_types:
    print("-", t)
# Out:
# Distinct problemTypes.descriptions.type values:
# - BASM (Broken Authentication & Session Management)
# - CWE
# - DoS (Denial of Service)
# - File Inclusion
# - Impact
# - Improper Authorization
# - Information Disclosure
# - Injection
# - Open Redirect
# - Other
# - PrivEsc (Privilege Escalation)
# - RCE (Remote Code Execution)
# - Reflected XSS
# - Security Misconfiguration
# - Stored XSS
# - cwe
# - problem_type
# - text
